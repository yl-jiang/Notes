# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# %matplotlib inline

# %%
img_path = '/home/dk/Dataset/indoor_video_8_4k_pngs/img-40.png'
img_bgr = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, figsize=[16, 10])
# ax.set_axis_off()
ax.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## image's shape

# %%
img_rgb.shape
# Out:
# (2048, 3584, 3)

# %% [markdown]
# ## image's pixels number

# %%
img_rgb.size
# Out:
# 22020096

# %%
np.prod(np.array(img_rgb.shape))
# Out:
# 22020096

# %% [markdown]
# ## image pixel's dtype

# %%
img_rgb.dtype
# Out:
# dtype('uint8')

# %%
cup = img_rgb[750:, 2200:2800, :]
img_rgb[750:, 0:(2800-2200), :] = cup

fig, ax = plt.subplots(1, figsize=[16, 10])
ax.set_axis_off()
ax.imshow(img_rgb)
plt.show()
