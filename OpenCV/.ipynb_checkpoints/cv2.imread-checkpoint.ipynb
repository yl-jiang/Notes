# %%
import cv2
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path = '/home/dk/Dataset/indoor_video_8_4k_pngs/img-56.png'
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, figsize=[16, 10])
ax.imshow(img_rgb)
ax.set_axis_off()
plt.show()
